# %% [markdown]
# # Process MASS data structure 2.0
# get sleep stages

# %%
import os
import pandas as pd
import numpy as np
import pyedflib
import pickle as pkl
from plotly import express as px
from matplotlib import pyplot as plt

# %%
edfpath="D:\SpinCo\MASS\edfs"
annopath="D:\SpinCo\MASS\\annotations"
signalspath="D:\SpinCo\MASS\signals"
stagespath="D:\SpinCo\MASS\stages"

# %% [markdown]
# ## Signals = Subjects -> SS
# we are assuming 1:1 relation signal:subject from now on, so the concepts are merged

# %%
allfiles=os.listdir(edfpath)
subjectIds=list()
extensions=list()
types=list()
edfFiles=list()
for file in allfiles:
    aux1=file.split(".")
    if aux1[1]=="edf":
        aux2=aux1[0].split(" ")
        aux3=aux2[0].split("-")
        subjectIds.append(aux3[2])
        extensions.append(aux1[1])
        types.append(aux2[1])
        edfFiles.append(file)

edfsData=pd.DataFrame({
    "subjectId":subjectIds,
    "edfFile":edfFiles,
    "extension":extensions,
    "type":types
})

# %%
edfsData.head(5)
# Out:
#   subjectId              edfFile extension  type
# 0      0001  01-02-0001 Base.edf       edf  Base
# 1      0001   01-02-0001 PSG.edf       edf   PSG
# 2      0002  01-02-0002 Base.edf       edf  Base
# 3      0002   01-02-0002 PSG.edf       edf   PSG
# 4      0003  01-02-0003 Base.edf       edf  Base

# %%
ssStages=edfsData[edfsData.type=="Base"].reset_index(drop=True)
ssStages
# Out:
#    subjectId              edfFile extension  type
# 0       0001  01-02-0001 Base.edf       edf  Base
# 1       0002  01-02-0002 Base.edf       edf  Base
# 2       0003  01-02-0003 Base.edf       edf  Base
# 3       0004  01-02-0004 Base.edf       edf  Base
# 4       0005  01-02-0005 Base.edf       edf  Base
# 5       0006  01-02-0006 Base.edf       edf  Base
# 6       0007  01-02-0007 Base.edf       edf  Base
# 7       0008  01-02-0008 Base.edf       edf  Base
# 8       0009  01-02-0009 Base.edf       edf  Base
# 9       0010  01-02-0010 Base.edf       edf  Base
# 10      0011  01-02-0011 Base.edf       edf  Base
# 11      0012  01-02-0012 Base.edf       edf  Base
# 12      0013  01-02-0013 Base.edf       edf  Base
# 13      0014  01-02-0014 Base.edf       edf  Base
# 14      0015  01-02-0015 Base.edf       edf  Base
# 15      0016  01-02-0016 Base.edf       edf  Base
# 16      0017  01-02-0017 Base.edf       edf  Base
# 17      0018  01-02-0018 Base.edf       edf  Base
# 18      0019  01-02-0019 Base.edf       edf  Base

# %%
subjectIds=list()
starts=list()
durations=list()
types=list()
comments=list()
files=list()
stages=list()
startTimes=list()

for ind, row in ssStages.iterrows():
    print("**********************************************")
    print(ind)
    print(row)
    fullPath=edfpath+"/"+row.edfFile
    signals, signal_headers, header = pyedflib.highlevel.read_edf(fullPath)
    thisStartTime=header['startdate']
    for anno in header['annotations']:
        subjectIds.append(row.subjectId)
        starts.append(anno[0])
        durations.append(anno[1])
        types.append('stage')
        comments.append(anno[2])
        startTimes.append(thisStartTime)
        if '?' in anno[2]:
            stages.append(np.nan)
        elif 'W' in anno[2]:
            stages.append(0)
        elif str(1) in anno[2]:
            stages.append(1)
        elif str(2) in anno[2]:
            stages.append(2)
        elif str(3) in anno[2]:
            stages.append(3)
        elif str(4) in anno[2]:
            stages.append(3)
        elif 'R' in anno[2]:
            stages.append(5)
        else:
            print("WARNING: you should never be here")
            break
            
    print("**********************************************")

""" #check
sum(np.array(samplerates)==np.array(aux))==len(samplerates) """

stageAnnotations=pd.DataFrame({
    'subjectId':subjectIds,
    'startTime':starts,
    'duration':durations,
    'type':types,
    'value':stages,
    'comment':comments,
    'fileDateTime':startTimes
})
# Out:
# **********************************************
# 0
# subjectId                   0001
# edfFile      01-02-0001 Base.edf
# extension                    edf
# type                        Base
# Name: 0, dtype: object
# **********************************************
# **********************************************
# 1
# subjectId                   0002
# edfFile      01-02-0002 Base.edf
# extension                    edf
# type                        Base
# Name: 1, dtype: object
# **********************************************
# **********************************************
# 2
# subjectId                   0003
# edfFile      01-02-0003 Base.edf
# extension                    edf
# type                        Base
# Name: 2, dtype: object
# **********************************************
# **********************************************
# 3
# subjectId                   0004
# edfFile      01-02-0004 Base.edf
# extension                    edf
# type                        Base
# Name: 3, dtype: object
# **********************************************
# **********************************************
# 4
# subjectId                   0005
# edfFile      01-02-0005 Base.edf
# extension                    edf
# type                        Base
# Name: 4, dtype: object
# **********************************************
# **********************************************
# 5
# subjectId                   0006
# edfFile      01-02-0006 Base.edf
# extension                    edf
# type                        Base
# Name: 5, dtype: object
# **********************************************
# **********************************************
# 6
# subjectId                   0007
# edfFile      01-02-0007 Base.edf
# extension                    edf
# type                        Base
# Name: 6, dtype: object
# **********************************************
# **********************************************
# 7
# subjectId                   0008
# edfFile      01-02-0008 Base.edf
# extension                    edf
# type                        Base
# Name: 7, dtype: object
# **********************************************
# **********************************************
# 8
# subjectId                   0009
# edfFile      01-02-0009 Base.edf
# extension                    edf
# type                        Base
# Name: 8, dtype: object
# **********************************************
# **********************************************
# 9
# subjectId                   0010
# edfFile      01-02-0010 Base.edf
# extension                    edf
# type                        Base
# Name: 9, dtype: object
# **********************************************
# **********************************************
# 10
# subjectId                   0011
# edfFile      01-02-0011 Base.edf
# extension                    edf
# type                        Base
# Name: 10, dtype: object
# **********************************************
# **********************************************
# 11
# subjectId                   0012
# edfFile      01-02-0012 Base.edf
# extension                    edf
# type                        Base
# Name: 11, dtype: object
# **********************************************
# **********************************************
# 12
# subjectId                   0013
# edfFile      01-02-0013 Base.edf
# extension                    edf
# type                        Base
# Name: 12, dtype: object
# **********************************************
# **********************************************
# 13
# subjectId                   0014
# edfFile      01-02-0014 Base.edf
# extension                    edf
# type                        Base
# Name: 13, dtype: object
# **********************************************
# **********************************************
# 14
# subjectId                   0015
# edfFile      01-02-0015 Base.edf
# extension                    edf
# type                        Base
# Name: 14, dtype: object
# **********************************************
# **********************************************
# 15
# subjectId                   0016
# edfFile      01-02-0016 Base.edf
# extension                    edf
# type                        Base
# Name: 15, dtype: object
# **********************************************
# **********************************************
# 16
# subjectId                   0017
# edfFile      01-02-0017 Base.edf
# extension                    edf
# type                        Base
# Name: 16, dtype: object
# **********************************************
# **********************************************
# 17
# subjectId                   0018
# edfFile      01-02-0018 Base.edf
# extension                    edf
# type                        Base
# Name: 17, dtype: object
# **********************************************
# **********************************************
# 18
# subjectId                   0019
# edfFile      01-02-0019 Base.edf
# extension                    edf
# type                        Base
# Name: 18, dtype: object
# **********************************************

# %% [markdown]
# ### Sinchronize with signal start time

# %%
stageAnnotations.head(5)
# Out:
#   subjectId       start   duration   type  value        comment  \
# 0      0001  561.000009  19.998720  stage    NaN  Sleep stage ?
# 1      0001  581.000009  20.002626  stage    NaN  Sleep stage ?
# 2      0001  601.000009  19.998720  stage    NaN  Sleep stage ?
# 3      0001  621.000009  19.998720  stage    NaN  Sleep stage ?
# 4      0001  641.000010  20.002626  stage    NaN  Sleep stage ?
#
#          fileDateTime
# 0 2000-01-01 23:00:59
# 1 2000-01-01 23:00:59
# 2 2000-01-01 23:00:59
# 3 2000-01-01 23:00:59
# 4 2000-01-01 23:00:59

# %%
from EDFlib.edfreader import EDFreader #<-need this to load datetime of the signals

allfiles=os.listdir(edfpath)
subjectIds=list()
extensions=list()
types=list()
edfFiles=list()
startTimes=list()

for file in allfiles:
    aux1=file.split(".")
    if aux1[1]=="edf":
        aux2=aux1[0].split(" ")
        aux3=aux2[0].split("-")
        subjectIds.append(aux3[2])
        extensions.append(aux1[1])
        types.append(aux2[1])
        edfFiles.append(file)
        reader=EDFreader(edfpath+"/"+file)
        startTimes.append(reader.getStartDateTime())

edfsData=pd.DataFrame({
    "subjectId":subjectIds,
    "edfFile":edfFiles,
    "extension":extensions,
    "type":types,
    "fileDateTime":startTimes
})

# %%
ssMetadata=edfsData[edfsData.type=="PSG"].reset_index(drop=True)
ssMetadata
# Out:
#    subjectId             edfFile extension type               fileDateTime
# 0       0001  01-02-0001 PSG.edf       edf  PSG 2000-01-01 23:00:59.241696
# 1       0002  01-02-0002 PSG.edf       edf  PSG 2000-01-01 22:35:58.036561
# 2       0003  01-02-0003 PSG.edf       edf  PSG 2000-01-01 00:33:32.658647
# 3       0004  01-02-0004 PSG.edf       edf  PSG 2000-01-01 23:23:02.767035
# 4       0005  01-02-0005 PSG.edf       edf  PSG 2000-01-01 22:22:11.859389
# 5       0006  01-02-0006 PSG.edf       edf  PSG 2000-01-01 00:02:19.084621
# 6       0007  01-02-0007 PSG.edf       edf  PSG 2000-01-01 23:17:16.949841
# 7       0008  01-02-0008 PSG.edf       edf  PSG 2000-01-01 23:45:03.904196
# 8       0009  01-02-0009 PSG.edf       edf  PSG 2000-01-01 23:48:54.761051
# 9       0010  01-02-0010 PSG.edf       edf  PSG 2000-01-01 00:02:39.746518
# 10      0011  01-02-0011 PSG.edf       edf  PSG 2000-01-01 00:07:38.047877
# 11      0012  01-02-0012 PSG.edf       edf  PSG 2000-01-01 22:59:00.764276
# 12      0013  01-02-0013 PSG.edf       edf  PSG 2000-01-01 22:41:22.937153
# 13      0014  01-02-0014 PSG.edf       edf  PSG 2000-01-01 23:15:18.604818
# 14      0015  01-02-0015 PSG.edf       edf  PSG 2000-01-01 23:59:04.693953
# 15      0016  01-02-0016 PSG.edf       edf  PSG 2000-01-01 00:09:27.373929
# 16      0017  01-02-0017 PSG.edf       edf  PSG 2000-01-01 00:27:18.897970
# 17      0018  01-02-0018 PSG.edf       edf  PSG 2000-01-01 22:30:52.893708
# 18      0019  01-02-0019 PSG.edf       edf  PSG 2000-01-01 23:55:22.911189

# %%
#1. Merge with ssMetadata to have fileDateTime from the signal in each annotation
annotationsMerged=pd.merge(stageAnnotations,ssMetadata,on='subjectId',suffixes=['','_sig'])
annotationsMerged
# Out:
#       subjectId     startTime   duration   type  value        comment  \
# 0          0001    561.000009  19.998720  stage    NaN  Sleep stage ?
# 1          0001    581.000009  20.002626  stage    NaN  Sleep stage ?
# 2          0001    601.000009  19.998720  stage    NaN  Sleep stage ?
# 3          0001    621.000009  19.998720  stage    NaN  Sleep stage ?
# 4          0001    641.000010  20.002626  stage    NaN  Sleep stage ?
# ...         ...           ...        ...    ...    ...            ...
# 27372      0019  26298.000362  20.002626  stage    NaN  Sleep stage ?
# 27373      0019  26318.000362  19.998720  stage    NaN  Sleep stage ?
# 27374      0019  26338.000363  19.998720  stage    NaN  Sleep stage ?
# 27375      0019  26358.000363  20.002626  stage    NaN  Sleep stage ?
# 27376      0019  26378.000363  13.717872  stage    NaN  Sleep stage ?
#
#              fileDateTime             edfFile extension type_sig  \
# 0     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# 1     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# 2     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# 3     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# 4     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# ...                   ...                 ...       ...      ...
# 27372 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
# 27373 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
# 27374 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
# 27375 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
# 27376 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
#
#                 fileDateTime_sig
# 0     2000-01-01 23:00:59.241696
# 1     2000-01-01 23:00:59.241696
# 2     2000-01-01 23:00:59.241696
# 3     2000-01-01 23:00:59.241696
# 4     2000-01-01 23:00:59.241696
# ...                          ...
# 27372 2000-01-01 23:55:22.911189
# 27373 2000-01-01 23:55:22.911189
# 27374 2000-01-01 23:55:22.911189
# 27375 2000-01-01 23:55:22.911189
# 27376 2000-01-01 23:55:22.911189
#
# [27377 rows x 11 columns]

# %%
#2. Operate using built-in datetime operations
annotationsMerged['annotationDelay']=annotationsMerged.apply(
    lambda row: (row.fileDateTime_sig-row.fileDateTime).total_seconds(),
    axis=1)
annotationsMerged[['type','subjectId','startTime','type','comment','annotationDelay']]
# Out:
#         type subjectId     startTime   type        comment  annotationDelay
# 0      stage      0001    561.000009  stage  Sleep stage ?         0.241696
# 1      stage      0001    581.000009  stage  Sleep stage ?         0.241696
# 2      stage      0001    601.000009  stage  Sleep stage ?         0.241696
# 3      stage      0001    621.000009  stage  Sleep stage ?         0.241696
# 4      stage      0001    641.000010  stage  Sleep stage ?         0.241696
# ...      ...       ...           ...    ...            ...              ...
# 27372  stage      0019  26298.000362  stage  Sleep stage ?         0.911189
# 27373  stage      0019  26318.000362  stage  Sleep stage ?         0.911189
# 27374  stage      0019  26338.000363  stage  Sleep stage ?         0.911189
# 27375  stage      0019  26358.000363  stage  Sleep stage ?         0.911189
# 27376  stage      0019  26378.000363  stage  Sleep stage ?         0.911189
#
# [27377 rows x 6 columns]

# %%
#3. Check that there is only one unique value for each combination of type_ann subjectId and labelerId ...
annotationsMerged[['type','subjectId','annotationDelay']].drop_duplicates().groupby(['subjectId']).describe()

#... in fact there is only one delay for each subjectId, the delay comes from the signal start time
# Out:
#           annotationDelay                                              \
#                     count      mean std       min       25%       50%
# subjectId
# 0001                  1.0  0.241696 NaN  0.241696  0.241696  0.241696
# 0002                  1.0  0.036561 NaN  0.036561  0.036561  0.036561
# 0003                  1.0  0.658647 NaN  0.658647  0.658647  0.658647
# 0004                  1.0  0.767035 NaN  0.767035  0.767035  0.767035
# 0005                  1.0  0.859389 NaN  0.859389  0.859389  0.859389
# 0006                  1.0  0.084621 NaN  0.084621  0.084621  0.084621
# 0007                  1.0  0.949841 NaN  0.949841  0.949841  0.949841
# 0008                  1.0  0.904196 NaN  0.904196  0.904196  0.904196
# 0009                  1.0  0.761051 NaN  0.761051  0.761051  0.761051
# 0010                  1.0  0.746518 NaN  0.746518  0.746518  0.746518
# 0011                  1.0  0.047877 NaN  0.047877  0.047877  0.047877
# 0012                  1.0  0.764276 NaN  0.764276  0.764276  0.764276
# 0013                  1.0  0.937153 NaN  0.937153  0.937153  0.937153
# 0014                  1.0  0.604818 NaN  0.604818  0.604818  0.604818
# 0015                  1.0  0.693953 NaN  0.693953  0.693953  0.693953
# 0016                  1.0  0.373929 NaN  0.373929  0.373929  0.373929
# 0017                  1.0  0.897970 NaN  0.897970  0.897970  0.897970
# 0018                  1.0  0.893708 NaN  0.893708  0.893708  0.893708
# 0019                  1.0  0.911189 NaN  0.911189  0.911189  0.911189
#
#
#                 75%       max
# subjectId
# 0001       0.241696  0.241696
# 0002       0.036561  0.036561
# 0003       0.658647  0.658647
# 0004       0.767035  0.767035
# 0005       0.859389  0.859389
# 0006       0.084621  0.084621
# 0007       0.949841  0.949841
# 0008       0.904196  0.904196
# 0009       0.761051  0.761051
# 0010       0.746518  0.746518
# 0011       0.047877  0.047877
# 0012       0.764276  0.764276
# 0013       0.937153  0.937153
# 0014       0.604818  0.604818
# 0015       0.693953  0.693953
# 0016       0.373929  0.373929
# 0017       0.897970  0.897970
# 0018       0.893708  0.893708
# 0019       0.911189  0.911189

# %%
#4. Now that we are sure of what we do, discount the delay from all start times:
annotationsMerged['originalStartTime']=annotationsMerged['startTime']
annotationsMerged['startTime']=annotationsMerged['startTime']-annotationsMerged['annotationDelay']
annotationsMerged
# Out:
#       subjectId     startTime   duration   type  value        comment  \
# 0          0001    560.758313  19.998720  stage    NaN  Sleep stage ?
# 1          0001    580.758313  20.002626  stage    NaN  Sleep stage ?
# 2          0001    600.758313  19.998720  stage    NaN  Sleep stage ?
# 3          0001    620.758313  19.998720  stage    NaN  Sleep stage ?
# 4          0001    640.758314  20.002626  stage    NaN  Sleep stage ?
# ...         ...           ...        ...    ...    ...            ...
# 27372      0019  26297.089173  20.002626  stage    NaN  Sleep stage ?
# 27373      0019  26317.089173  19.998720  stage    NaN  Sleep stage ?
# 27374      0019  26337.089174  19.998720  stage    NaN  Sleep stage ?
# 27375      0019  26357.089174  20.002626  stage    NaN  Sleep stage ?
# 27376      0019  26377.089174  13.717872  stage    NaN  Sleep stage ?
#
#              fileDateTime             edfFile extension type_sig  \
# 0     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# 1     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# 2     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# 3     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# 4     2000-01-01 23:00:59  01-02-0001 PSG.edf       edf      PSG
# ...                   ...                 ...       ...      ...
# 27372 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
# 27373 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
# 27374 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
# 27375 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
# 27376 2000-01-01 23:55:22  01-02-0019 PSG.edf       edf      PSG
#
#                 fileDateTime_sig  annotationDelay  originalStartTime
# 0     2000-01-01 23:00:59.241696         0.241696         561.000009
# 1     2000-01-01 23:00:59.241696         0.241696         581.000009
# 2     2000-01-01 23:00:59.241696         0.241696         601.000009
# 3     2000-01-01 23:00:59.241696         0.241696         621.000009
# 4     2000-01-01 23:00:59.241696         0.241696         641.000010
# ...                          ...              ...                ...
# 27372 2000-01-01 23:55:22.911189         0.911189       26298.000362
# 27373 2000-01-01 23:55:22.911189         0.911189       26318.000362
# 27374 2000-01-01 23:55:22.911189         0.911189       26338.000363
# 27375 2000-01-01 23:55:22.911189         0.911189       26358.000363
# 27376 2000-01-01 23:55:22.911189         0.911189       26378.000363
#
# [27377 rows x 13 columns]

# %%
#5. clean the dataframe
cleanedAnnotations=annotationsMerged[['subjectId','type','startTime','duration','value','comment']]
cleanedAnnotations
# Out:
#       subjectId   type     startTime   duration  value        comment
# 0          0001  stage    560.758313  19.998720    NaN  Sleep stage ?
# 1          0001  stage    580.758313  20.002626    NaN  Sleep stage ?
# 2          0001  stage    600.758313  19.998720    NaN  Sleep stage ?
# 3          0001  stage    620.758313  19.998720    NaN  Sleep stage ?
# 4          0001  stage    640.758314  20.002626    NaN  Sleep stage ?
# ...         ...    ...           ...        ...    ...            ...
# 27372      0019  stage  26297.089173  20.002626    NaN  Sleep stage ?
# 27373      0019  stage  26317.089173  19.998720    NaN  Sleep stage ?
# 27374      0019  stage  26337.089174  19.998720    NaN  Sleep stage ?
# 27375      0019  stage  26357.089174  20.002626    NaN  Sleep stage ?
# 27376      0019  stage  26377.089174  13.717872    NaN  Sleep stage ?
#
# [27377 rows x 6 columns]

# %%
#6. save a csv
cleanedAnnotations.to_csv(stagespath+"\\stages.csv",index=False)
